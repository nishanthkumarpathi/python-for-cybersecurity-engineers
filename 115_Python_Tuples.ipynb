# %%
protocolTuple = ("HTTP", "HTTPS", "FTP", "SFTP", "SSH")
print(protocolTuple)
# Out:
# ('HTTP', 'HTTPS', 'FTP', 'SFTP', 'SSH')

# %%
# pop from tuple
protocolTuple.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\npathi\Desktop\PyCSE\03_Python_Tuples.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # pop from tuple
# ----> <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> protocolTuple.pop()
#       <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> print(protocolTuple)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
# remove from tuple
protocolTuple.remove("FTP")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\npathi\Desktop\PyCSE\03_Python_Tuples.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # remove from tuple
# ----> <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> protocolTuple.remove("FTP")
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
# append
protocolTuple.append("FTP")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\npathi\Desktop\PyCSE\03_Python_Tuples.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # append
# ----> <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> protocolTuple.append("FTP")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# replace the value
protocolTuple[1] = "HTTPS"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\npathi\Desktop\PyCSE\03_Python_Tuples.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # replace the value
# ----> <a href='vscode-notebook-cell:/c%3A/Users/npathi/Desktop/PyCSE/03_Python_Tuples.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> protocolTuple[1] = "HTTPS"
#
# TypeError: 'tuple' object does not support item assignment
